# %%
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# done
# Building wheels for collected packages: imutils
# done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25859 sha256=ffbc40c912557160b24841a52663c2695dfdf9ec18b33f443898cb50ace45ee1
#   Stored in directory: /root/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %% [markdown]
# ## import Library

# %%
#import library
import matplotlib.pyplot as plt
import numpy as np
import imutils #image utilize
import cv2
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## read images and resizing

# %%
plt.figure(figsize=(14,10))
imagedata = plt.imread("../input/catimges/cat.jpg")
plt.imshow(imagedata)
plt.grid(False)
plt.show()

# %%
#show the shape
len(imagedata.shape)
# Out:
# 3

# %% [markdown]
# ## convert color from BGR to RGB

# %%
def catimageShow(imageTitle, image):
    if len(image.shape) == 3:
        imageVariable = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     if image.shape[2] == 1:
#     imageVariable = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    plt.figure(figsize=(4, 2))
    plt.imshow(imageVariable)
    plt.title(imageTitle)
    plt.show() #ignore hexadecimal

# %%
imagedata.shape
# Out:
# (280, 300, 3)

# %% [markdown]
# ## Spliting image to R, G, B

# %%
cv2.split(imagedata) #show (B,G, R) withinn 3 arrays
# Out:
# (array([[ 39,  39,  40, ..., 207, 202, 201],
#         [ 40,  40,  40, ..., 203, 199, 197],
#         [ 40,  40,  40, ..., 199, 199, 199],
#         ...,
#         [ 32,  30,  26, ...,  36,  41,  57],
#         [ 32,  30,  26, ...,  42,  44,  55],
#         [ 32,  29,  25, ...,  51,  42,  40]], dtype=uint8),
#  array([[ 44,  44,  44, ..., 204, 199, 198],
#         [ 45,  45,  44, ..., 200, 196, 194],
#         [ 45,  45,  44, ..., 195, 194, 194],
#         ...,
#         [ 30,  28,  24, ...,  23,  30,  46],
#         [ 30,  28,  24, ...,  29,  34,  45],
#         [ 30,  27,  23, ...,  38,  32,  30]], dtype=uint8),
#  array([[ 40,  40,  43, ..., 173, 166, 163],
#         [ 41,  41,  43, ..., 169, 163, 159],
#         [ 41,  41,  43, ..., 166, 164, 162],
#         ...,
#         [ 31,  29,  25, ...,  17,  24,  40],
#         [ 31,  29,  25, ...,  21,  25,  36],
#         [ 31,  28,  24, ...,  30,  23,  21]], dtype=uint8))

# %% [markdown]
# ## Make image histogram

# %%
def imageHistogram(image, imageTitle, mask=None):
    color_Channel= cv2.split(image) #split the raw image with BGR
    color_com = ('b','g','r')
    plt.figure(figsize=(4,2))
    plt.title(imageTitle)
    plt.xlabel("Bins") #make pillar
    plt.ylabel("pixel information")
    
    for (color_Channel, color_com) in zip(color_Channel, color_com):
        histogram =cv2.calcHist([color_Channel],[0],mask,[256], [0,256])#calcHist([color_Channel=3],B=0,Mask=None,[bins], [range])
        plt.plot(histogram, color= color_com)
        plt.xlim([0,256])
        plt.show()

# %% [markdown]
# ## Take a new image and apply histogram

# %%
image_argument={"Image": "../input/catnew/catim.jpg"}
image= cv2.imread(image_argument["Image"])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
samplehisto = cv2.calcHist([image],[0], None, [256], [0,256])
plt.figure(figsize=(4,2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel information")
plt.plot(samplehisto) #show the linegraph
plt.show()

# %% [markdown]
# ## Make histogram for Green color

# %%
image_argument={"Image": "../input/catnew/catim.jpg"}
image= cv2.imread(image_argument["Image"])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
samplehisto = cv2.calcHist([image],[1], None, [256], [0,256])
plt.figure(figsize=(4,2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel information")
plt.plot(samplehisto) #show the linegraph
plt.show()

# %% [markdown]
# # make histogram for Red color image

# %%
image_argument={"Image": "../input/catnew/catim.jpg"}
image= cv2.imread(image_argument["Image"])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
samplehisto = cv2.calcHist([image],[2], None, [256], [0,256])
plt.figure(figsize=(4,2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel information")
plt.plot(samplehisto) #show the linegraph
plt.show()

# %% [markdown]
# # combine color channel

# %%
color_Channel = cv2.split(image)
color_com = ('b', 'g', 'r')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])

# %%
cv2.split(image) #BGR
# Out:
# (array([[152, 154, 156, ..., 180, 180, 180],
#         [153, 154, 157, ..., 180, 180, 180],
#         [153, 155, 158, ..., 180, 180, 180],
#         ...,
#         [189, 201, 186, ..., 255, 253, 235],
#         [197, 184, 186, ..., 242, 237, 238],
#         [185, 177, 200, ..., 255, 251, 255]], dtype=uint8),
#  array([[160, 162, 164, ..., 192, 192, 192],
#         [161, 162, 165, ..., 192, 192, 192],
#         [161, 163, 166, ..., 192, 192, 192],
#         ...,
#         [174, 186, 170, ..., 255, 250, 232],
#         [180, 167, 168, ..., 239, 234, 235],
#         [168, 160, 182, ..., 255, 248, 255]], dtype=uint8),
#  array([[171, 173, 177, ..., 208, 208, 208],
#         [172, 173, 178, ..., 208, 208, 208],
#         [174, 176, 179, ..., 208, 208, 208],
#         ...,
#         [153, 167, 155, ..., 250, 245, 227],
#         [162, 149, 154, ..., 234, 229, 230],
#         [150, 144, 168, ..., 250, 243, 250]], dtype=uint8))

# %% [markdown]
# ## Blue

# %%
color_Channel = cv2.split(image) #BGR
color_com = ('b', 'g', 'r')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])
    plt.show()

# %%
#Make it RGB
color_Channel = cv2.split(image) #BGR
color_com = ('r', 'g', 'b')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])
    plt.show()

# %% [markdown]
# ##

# %%
color =["B","G", "R"]
fig= plt.figure(figsize=(20,18))
ax= fig.add_subplot(131)
hist= cv2.calcHist([color_Channel[1], color_Channel[0]], [0,1], None, [32,32], [0,256,0,256]) #this is for color_channel 1 and 2 
p = ax.imshow(hist,  interpolation="nearest")
ax.set_title("This is for color channel green and blue")
plt.colorbar(p)



ax= fig.add_subplot(132)
hist= cv2.calcHist([color_Channel[1], color_Channel[2]], [0,1], None, [32,32], [0,256,0,256]) #this is for color_channel 1 and 2 
p = ax.imshow(hist,  interpolation="nearest")
ax.set_title("This is for color channel green and red ")
plt.colorbar(p)

ax = fig.add_subplot(133)
hist = cv2.calcHist([color_Channel[0], color_Channel[2]], [0, 1], None, [32, 32], [0, 256, 0, 256])
p = ax.imshow(hist, interpolation = "nearest")
ax.set_title("Image Generate for Blue and Red")
plt.colorbar(p)
print("image shape: {} with {}".format(hist.shape, hist.flatten())) # used flatten to make it one
# Out:
# image shape: (32, 32) with [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# ## read the image

# %%
image= cv2.imread("../input/catimges/cat.jpg")
imageHistogram(image, "Image Title")
catimageShow("original image", image)

# %%
image.shape[:2]
# Out:
# (280, 300)

# %%
def catimageShow(imageTitle, image):
    imageVariable = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(4, 2))
    plt.imshow(imageVariable)
    plt.title(imageTitle)
    plt.show()

# %% [markdown]
# ## mask is used to localize a object

# %%
mask =np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (60,90),(100,120), 255, -1) #255 is white
catimageShow("Applied Mask", mask)

# %%
#mask is used to localize a object
mask =np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (60,90),(100,120), 25, -1) #255 is white
catimageShow("Applied Mask", mask)

# %% [markdown]
# ## show Blur image

# %%
image = cv2.imread("../input/catimges/cat.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurImage = cv2.GaussianBlur(gray, (5, 5), 0)
catimageShow("Orginal Image", image)
catimageShow("Blur Image", blurImage)

# %%
cannyBlurWide = cv2.Canny(blurImage, 20, 250)
cannyBlurMiddle = cv2.Canny(blurImage, 15, 120)
cannyBlurFit = cv2.Canny(blurImage, 240, 250)

catimageShow("cannyBlurWide",cannyBlurWide)
catimageShow("cannyBlurMiddle", cannyBlurMiddle)
catimageShow("cannyBlurFit", cannyBlurFit)
